# %% [markdown]
# ## Prac1: Data Cleaning

# %% [markdown]
# #### Apply data cleaning techniques on any dataset (e.g., Paper Reviews dataset in UCI repository). Techniques may include handling missing values, outliers and inconsistent values. A set of validation rules can be prepared based on the dataset and validations can be performed.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('fruit_classification_dataset.csv')
print(df.head())
# Out:
#    size (cm)  shape  weight (g)  avg_price (₹)   color  taste     fruit_name
# 0       25.4  round      3089.2          137.1   green  sweet     watermelon
# 1       24.6  round      3283.9          163.8   green  sweet     watermelon
# 2        7.8  round       319.0           91.3   green  sweet  custard apple
# 3       20.0   oval      1607.0           85.7  orange  sweet         papaya
# 4       10.2   long       131.5           37.8  yellow  sweet         banana

# %% [markdown]
# ### 1. Handling Missing Value

# %%
# for numeric columns -> replace missing values with median
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# %%
# for categorical columns -> replace missing values with mode
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])

# %% [markdown]
# ### 2. Handling Outliers (z-score method)

# %%
# handling outliers z-score method
for col in num_cols:
    mean = df[col].mean()
    std = df[col].std()
    z_scores = (df[col] - mean) / std

# %%
# replace outliner > 3 and < -3 with median
# df.loc[z_scores > 3, num_cols] = df[num_cols].median()
# df.loc[z_scores < -3, num_cols] = df[num_cols].median()

df.loc[z_scores > 3, col] = df[col].median()
df.loc[z_scores < -3, col] = df[col].median()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 # replace outliner > 3 and < -3 with median
# ----> 2 df.loc[z_scores > 3, num_cols] = df[num_cols].median()
#       3 df.loc[z_scores < -3, num_cols] = df[num_cols].median()
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexing.py:908, in _LocationIndexer.__setitem__(self, key, value)
#     906     maybe_callable = com.apply_if_callable(key, self.obj)
#     907     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 908 indexer = self._get_setitem_indexer(key)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexing.py:775, in _LocationIndexer._get_setitem_indexer(self, key)
#     772 if isinstance(key, tuple):
#     773     with suppress(IndexingError):
#     774         # suppress "Too many indexers"
# --> 775         return self._convert_tuple(key)
#     777 if isinstance(key, range):
#     778     # GH#45479 test_loc_setitem_range_key
#     779     key = list(key)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexing.py:990, in _LocationIndexer._convert_tuple(self, key)
#     986 @final
#     987 def _convert_tuple(self, key: tuple) -> tuple:
#     988     # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     989     self._validate_key_length(key)
# --> 990     keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     991     return tuple(keyidx)
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexing.py:1523, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1521         return key
#    1522     else:
# -> 1523         return self._get_listlike_indexer(key, axis)[1]
#    1524 else:
#    1525     try:
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexing.py:1559, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 ax = self.obj._get_axis(axis)
#    1557 axis_name = self.obj._get_axis_name(axis)
# -> 1559 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1561 return keyarr, indexer
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexes/base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([                    ('s', 'i', 'z', 'e', ' ', '(', 'c', 'm', ')'),\n                      ('w', 'e', 'i', 'g', 'h', 't', ' ', '(', 'g', ')'),\n       ('a', 'v', 'g', '_', 'p', 'r', 'i', 'c', 'e', ' ', '(', '₹', ')')],\n      dtype='object')] are in the [index]"

# %% [markdown]
# ### 3. Fixing Inconsistent Values

# %% [markdown]
# if()

# %% [markdown]
# ### 4. Validation Rules
